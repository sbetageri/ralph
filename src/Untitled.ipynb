# %%
import torch
import LRWDataset

# %% [markdown]
# /Users/sri/P/audio-assisted-lip-reading/data/data_files.csv

# %%
root_dir = '/Users/sri/P/audio-assisted-lip-reading/data/'
clean_files = 'dev/dev.csv'
dataset = LRWDataset.LRWDataset(root_dir, clean_files, is_dev=True)

# %%
dataset[9]
# Out:
# (tensor([[[[  4.,   4.,  16.],
#            [  4.,   4.,  16.],
#            [  4.,   4.,  16.],
#            ...,
#            [ 46.,  32.,  34.],
#            [ 46.,  32.,  34.],
#            [ 46.,  32.,  34.]],
#
#           [[  4.,   4.,  16.],
#            [  4.,   4.,  16.],
#            [  4.,   4.,  16.],
#            ...,
#            [ 46.,  32.,  34.],
#            [ 46.,  32.,  34.],
#            [ 46.,  32.,  34.]],
#
#           [[  4.,   4.,  16.],
#            [  4.,   4.,  16.],
#            [  4.,   4.,  16.],
#            ...,
#            [ 45.,  31.,  33.],
#            [ 46.,  32.,  34.],
#            [ 46.,  32.,  34.]],
#
#           ...,
#
#           [[  4.,   2.,  24.],
#            [  4.,   2.,  24.],
#            [  4.,   2.,  24.],
#            ...,
#            [ 76.,  40.,  53.],
#            [ 76.,  40.,  53.],
#            [ 76.,  40.,  53.]],
#
#           [[  4.,   2.,  24.],
#            [  4.,   2.,  24.],
#            [  4.,   2.,  24.],
# ...
